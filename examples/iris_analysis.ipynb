# %%
from dotenv import load_dotenv
load_dotenv(".env")

from sklearn.datasets import load_iris
import numpy as np
import numpyai_dashboard as npi

from rich.console import Console

# %%
c = Console()

# %%
iris = load_iris()
X, y = iris.data, iris.target
print(isinstance(X, np.ndarray) and isinstance(y, np.ndarray))
# Out:
# True

# %%
sess = npi.NumpyAISession([X, y], verbose=False)
diag = npi.Diagnosis(sess)

# %%
steps = diag.steps(task="Give me the exact and pithy steps to decide which machine learning model to use. Don't go into the Machine Learning side, rather use simple data-analysis. You should not give more than seven steps.")
# Out:
# ────────────────────────────────────────────────── LLM Response ───────────────────────────────────────────────────
# ╭────────────────────────────────────────────── Data Analysis Steps ──────────────────────────────────────────────╮
# │ [ "1. Confirm Data Types and Problem Type: Verify that 'arr1' contains numerical features and 'arr2' contains   │
# │ discrete, categorical labels. This confirms a supervised classification problem where 'arr1' is the input and   │
# │ 'arr2' is the target. The data types are float64 for features and int64 for labels. Diagnosis: If 'arr2' were   │
# │ continuous, it would indicate a regression problem; if 'arr1' had non-numeric types, encoding would be needed.  │
# │ Output of this step is the confirmed problem type.", "2. Confirm Absence of Missing Values: Use np.isnan on     │
# │ 'arr1' to ensure there are no missing data points. Based on metadata, 'arr1' has no NaNs. Diagnosis: If NaNs    │
# │ were present, imputation or row removal would be necessary, influencing data completeness for modeling. This    │
# │ step confirms data readiness for analysis.", "3. Analyze Feature Distributions: Calculate descriptive           │
# │ statistics for each column in 'arr1' (e.g., np.mean, np.std, np.min, np.max). This helps understand the range,  │
# │ spread, and central tendency of features. Diagnosis: Features with vastly different scales or highly skewed     │
# │ distributions might require standardization or normalization (e.g., for distance-based models like SVMs, K-NN,  │
# │ or linear models). Tree-based models are generally less sensitive to scaling. Output leads to decisions about   │
# │ data preprocessing.", "4. Examine Target Class Distribution: Determine the unique values in 'arr2' and their    │
# │ counts using np.unique with return_counts=True. Diagnosis: Significant imbalances between class counts          │
# │ ('zeros_count': 50, 'non_zeros_count': 100 which are 1s and 2s, but overall 50 for 0, 50 for 1, 50 for 2        │
# │ according to preview for arr2) indicate that models might struggle with minority classes, requiring strategies  │
# │ like resampling (oversampling/undersampling) or weighted loss functions, and consideration of metrics beyond    │
# │ simple accuracy. Output informs strategies for handling imbalanced data.", "5. Assess Feature Separability by   │
# │ Class: Group 'arr1' features by the corresponding labels in 'arr2' and compute separate descriptive statistics  │
# │ (e.g., np.mean, np.median) for each feature within each class. Diagnosis: Clear separation of feature           │
# │ ranges/means across classes suggests a simpler model (e.g., Logistic Regression, Linear SVM) might perform      │
# │ well. High overlap indicates the need for more complex, non-linear models (e.g., Decision Trees, Random         │
# │ Forests, Neural Networks). Output helps gauge inherent complexity of the decision boundary.", "6. Evaluate      │
# │ Feature-to-Feature Correlation: Calculate the pairwise correlation matrix of features in 'arr1' using           │
# │ np.corrcoef. Diagnosis: High correlations between features (multicollinearity) can affect the stability and     │
# │ interpretability of coefficients in linear models (e.g., Logistic Regression) and some kernel-based methods. It │
# │ might suggest a need for dimensionality reduction or feature selection. Tree-based models are generally more    │
# │ robust to correlated features. Output guides decisions on feature engineering or selection." ]                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
for step in steps:
    try:
        vals = sess.chat(step)
        print(vals)
    except:
        c.print(f"The following step failed: {step}")
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: 1. **Confirm Data Types and Problem Type**: Verify that 'arr1' contains numerical features and 'arr2'    │
# │ contains discrete, categorical labels. This confirms a supervised classification problem where 'arr1' is the    │
# │ input and 'arr2' is the target. The data types are float64 for features and int64 for labels. Diagnosis: If     │
# │ 'arr2' were continuous, it would indicate a regression problem; if 'arr1' had non-numeric types, encoding would │
# │ be needed. Output of this step is the confirmed problem type.                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value='Supervised Classification' code='if arr1.dtype == np.float64 and arr2.dtype == np.int64:\n    problem_type = "Supervised Classification"\nelif arr1.dtype == np.float64 and (arr2.dtype == np.float64 or arr2.dtype == np.float32):\n    problem_type = "Regression"\nelse:\n    problem_type = "Encoding needed for arr1 or other problem type"\n\noutput = problem_type\nmetadata = "Confirmed problem type based on data types"' description='Confirmed problem type based on data types' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=2 errors=['Attempt 1: judgment rejected: The query asks to verify data types and then state the problem type. The code only states the problem type without performing the verification steps.']
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: 2. **Confirm Absence of Missing Values**: Use `np.isnan` on 'arr1' to ensure there are no missing data   │
# │ points. Based on metadata, 'arr1' has no NaNs. Diagnosis: If NaNs were present, imputation or row removal would │
# │ be necessary, influencing data completeness for modeling. This step confirms data readiness for analysis.       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value=True code='output = not np.isnan(arr1).any()\nmetadata = "boolean: absence of missing values confirmed"' description='boolean: absence of missing values confirmed' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=1 errors=[]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: 3. **Analyze Feature Distributions**: Calculate descriptive statistics for each column in 'arr1' (e.g.,  │
# │ `np.mean`, `np.std`, `np.min`, `np.max`). This helps understand the range, spread, and central tendency of      │
# │ features. Diagnosis: Features with vastly different scales or highly skewed distributions might require         │
# │ standardization or normalization (e.g., for distance-based models like SVMs, K-NN, or linear models).           │
# │ Tree-based models are generally less sensitive to scaling. Output leads to decisions about data preprocessing.  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value={'mean': array([5.84333333, 3.05733333, 3.758     , 1.19933333]), 'std': array([0.82530129, 0.43441097, 1.75940407, 0.75969263]), 'min': array([4.3, 2. , 1. , 0.1]), 'max': array([7.9, 4.4, 6.9, 2.5])} code='output = {\n    "mean": np.mean(arr1, axis=0),\n    "std": np.std(arr1, axis=0),\n    "min": np.min(arr1, axis=0),\n    "max": np.max(arr1, axis=0)\n}\nmetadata = "Descriptive statistics (mean, std, min, max) for each column of arr1"' description='Descriptive statistics (mean, std, min, max) for each column of arr1' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=1 errors=[]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: 4. **Examine Target Class Distribution**: Determine the unique values in 'arr2' and their counts using   │
# │ `np.unique` with `return_counts=True`. Diagnosis: Significant imbalances between class counts ('zeros_count':   │
# │ 50, 'non_zeros_count': 100 which are 1s and 2s, but overall 50 for 0, 50 for 1, 50 for 2 according to preview   │
# │ for arr2) indicate that models might struggle with minority classes, requiring strategies like resampling       │
# │ (oversampling/undersampling) or weighted loss functions, and consideration of metrics beyond simple accuracy.   │
# │ Output informs strategies for handling imbalanced data.                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value={'unique_values': array([0, 1, 2]), 'counts': array([50, 50, 50])} code='unique_values, counts = np.unique(arr2, return_counts=True)\noutput = {"unique_values": unique_values, "counts": counts}\nmetadata = "dictionary: unique values in arr2 and their counts"' description='dictionary: unique values in arr2 and their counts' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=1 errors=[]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: 5. **Assess Feature Separability by Class**: Group 'arr1' features by the corresponding labels in 'arr2' │
# │ and compute separate descriptive statistics (e.g., `np.mean`, `np.median`) for each feature within each class.  │
# │ Diagnosis: Clear separation of feature ranges/means across classes suggests a simpler model (e.g., Logistic     │
# │ Regression, Linear SVM) might perform well. High overlap indicates the need for more complex, non-linear models │
# │ (e.g., Decision Trees, Random Forests, Neural Networks). Output helps gauge inherent complexity of the decision │
# │ boundary.                                                                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value={'class_0': {'mean': array([5.006, 3.428, 1.462, 0.246]), 'median': array([5. , 3.4, 1.5, 0.2])}, 'class_1': {'mean': array([5.936, 2.77 , 4.26 , 1.326]), 'median': array([5.9 , 2.8 , 4.35, 1.3 ])}, 'class_2': {'mean': array([6.588, 2.974, 5.552, 2.026]), 'median': array([6.5 , 3.  , 5.55, 2.  ])}} code='classes = np.unique(arr2)\noutput = {}\n\nfor cls in classes:\n    # Select features for the current class\n    features_for_class = arr1[arr2 == cls]\n    \n    # Calculate mean and median for each feature within this class\n    mean_features = np.mean(features_for_class, axis=0)\n    median_features = np.median(features_for_class, axis=0)\n    \n    output[f"class_{int(cls)}"] = {\n        "mean": mean_features,\n        "median": median_features\n    }\nmetadata = "Dictionary of descriptive statistics (mean, median) for each feature, grouped by class."' description='Dictionary of descriptive statistics (mean, median) for each feature, grouped by class.' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=1 errors=[]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: 6. **Evaluate Feature-to-Feature Correlation**: Calculate the pairwise correlation matrix of features in │
# │ 'arr1' using `np.corrcoef`. Diagnosis: High correlations between features (multicollinearity) can affect the    │
# │ stability and interpretability of coefficients in linear models (e.g., Logistic Regression) and some            │
# │ kernel-based methods. It might suggest a need for dimensionality reduction or feature selection. Tree-based     │
# │ models are generally more robust to correlated features. Output guides decisions on feature engineering or      │
# │ selection.                                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value=array([[ 1.        , -0.11756978,  0.87175378,  0.81794113],
#        [-0.11756978,  1.        , -0.4284401 , -0.36612593],
#        [ 0.87175378, -0.4284401 ,  1.        ,  0.96286543],
#        [ 0.81794113, -0.36612593,  0.96286543,  1.        ]]) code='output = np.corrcoef(arr1.T)\nmetadata = "2D array: pairwise correlation matrix of features in arr1"' description='2D array: pairwise correlation matrix of features in arr1' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=1 errors=[]
