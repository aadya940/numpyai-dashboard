# %%
from dotenv import load_dotenv
load_dotenv(".env")

import numpyai_dashboard as npi
import numpy as np

# %% [markdown]
# ### Natural language imputation

# %%
# Sample data with NaNs
data = np.array([[1, 2, 3, 4, 5, np.nan], [np.nan, 3, 5, 3.1415, 2, 2]])
arr = npi.array(data)

# %% [markdown]
# ### Natural language imputation

# %%
imputed_arr = arr.chat("Impute missing values with NumPy.")
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Impute missing values with NumPy.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ✓ Judgment passed!

# %% [markdown]
# ### Basic operations

# %%
arr2 = npi.array(data * 2)
print("Addition:\n", (arr + arr2).data)
print("Subtraction:\n", (arr - arr2).data)
print("Multiplication:\n", (arr * arr2).data)
print("Division:\n", (arr / arr2).data)
# Out:
# Addition:
#  [[ 3.      6.      9.     12.     15.         nan]
#  [    nan  9.     15.      9.4245  6.      6.    ]]
# Subtraction:
#  [[-1.     -2.     -3.     -4.     -5.         nan]
#  [    nan -3.     -5.     -3.1415 -2.     -2.    ]]
# Multiplication:
#  [[ 2.         8.        18.        32.        50.               nan]
#  [       nan 18.        50.        19.7380445  8.         8.       ]]
# Division:
#  [[0.5 0.5 0.5 0.5 0.5 nan]
#  [nan 0.5 0.5 0.5 0.5 0.5]]

# %% [markdown]
# ### Scalar operations

# %%
print("Scalar multiplication:\n", (arr * 3).data)
print("Scalar addition:\n", (10 + arr).data)
# Out:
# Scalar multiplication:
#  [[ 3.      6.      9.     12.     15.         nan]
#  [    nan  9.     15.      9.4245  6.      6.    ]]
# Scalar addition:
#  [[11.     12.     13.     14.     15.         nan]
#  [    nan 13.     15.     13.1415 12.     12.    ]]

# %% [markdown]
# ### Advanced operations

# %%
print("Matrix multiplication:\n", (arr @ arr2.T).data)
print("Mean:\n", arr.mean(axis=0))
print("Max:\n", arr.max(axis=1))
# Out:
# Matrix multiplication:
#  [[nan nan]
#  [nan nan]]
# Mean:
#  numpyai_dashboard.array(shape=(6,), dtype=float64)
# Max:
#  numpyai_dashboard.array(shape=(2,), dtype=float64)

# %% [markdown]
# ### Indexing, slicing, and reshaping

# %%
print("Slice:", arr[0, 1:4].data)
print("Reshape:\n", arr.reshape(3, 4).data)
# Out:
# Slice: [2. 3. 4.]
# Reshape:
#  [[1.     2.     3.     4.    ]
#  [5.        nan    nan 3.    ]
#  [5.     3.1415 2.     2.    ]]

# %% [markdown]
# ### Complex queries

# %%
complex_arr = npi.array(np.random.rand(10, 10))
# Increase Max Tries for Complex Queries.
complex_arr.MAX_TRIES = 5

corr_matrix = complex_arr.chat("Compute correlation matrix")
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Compute correlation matrix                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ✓ Judgment passed!

# %%
eigen_result = complex_arr.chat("Find eigenvectors and eigenvalues")
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Find eigenvectors and eigenvalues                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ✓ Judgment passed!

# %% [markdown]
# ### Working with Multiple Arrays

# %%
# Define Arrays
arr1 = np.array([[1, 2, 3], [4, 5, 6]])
arr2 = np.random.random((2, 3))

# %%
# Start a NumpyAISession
sess = npi.NumpyAISession([arr1, arr2])

# %%
imputed_array = sess.chat("Impute the first array with the mean of the second array.")
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Impute the first array with the mean of the second array.                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# A complex problem.
sess.chat("Multiply the second array by the sum of the fourier transform of the first array.")
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Multiply the second array by the sum of the fourier transform of the first array.                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# array([[12.46866544+0.j, 10.45330625+0.j,  9.57653628+0.j],
#        [13.46227246+0.j, 13.3239711 +0.j,  5.79021481+0.j]])
