# %%
from dotenv import load_dotenv
load_dotenv(".env")

import numpyai_dashboard as npi
import numpy as np

# %%
np.random.seed(42)  # For consistent results

# %%
# Simulate conversions for group A (10% conversion rate)
a_data = np.random.binomial(n=1, p=0.10, size=1000)

# Simulate conversions for group B (12% conversion rate)
b_data = np.random.binomial(n=1, p=0.12, size=1000)

# %%
# Start a NumPyAI session with both arrays
sess = npi.NumpyAISession([a_data, b_data], verbose=True)

# %%
print(sess.chat("What is the conversion rate of each group?"))  # → Should return two means
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: What is the conversion rate of each group?                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │   1 conversion_rate_arr1 = np.mean(arr1)                                                                        │
# │   2 conversion_rate_arr2 = np.mean(arr2)                                                                        │
# │   3                                                                                                             │
# │   4 output = {                                                                                                  │
# │   5     "group1_conversion_rate": conversion_rate_arr1,                                                         │
# │   6     "group2_conversion_rate": conversion_rate_arr2                                                          │
# │   7 }                                                                                                           │
# │   8 metadata = "dictionary: conversion rate of each group"                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# {'group1_conversion_rate': np.float64(0.1), 'group2_conversion_rate': np.float64(0.112)}
# dictionary: conversion rate of each group
# ╭─────────────────────────────────────────────────── Judgment ────────────────────────────────────────────────────╮
# │ ✓ correctly interprets the query                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  {'group1_conversion_rate': np.float64(0.1), 'group2_conversion_rate': np.float64(0.112)}                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value={'group1_conversion_rate': np.float64(0.1), 'group2_conversion_rate': np.float64(0.112)} code='conversion_rate_arr1 = np.mean(arr1)\nconversion_rate_arr2 = np.mean(arr2)\n\noutput = {\n    "group1_conversion_rate": conversion_rate_arr1,\n    "group2_conversion_rate": conversion_rate_arr2\n}\nmetadata = "dictionary: conversion rate of each group"' description='dictionary: conversion rate of each group' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=1 errors=[]

# %%
# Chat: Perform a z-test to compare the conversion rates
print(sess.chat("Perform a z-test to determine if the difference is statistically significant."))
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Perform a z-test to determine if the difference is statistically significant.                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 n1 = len(arr1)                                                                                             │
# │    2 n2 = len(arr2)                                                                                             │
# │    3                                                                                                            │
# │    4 x1 = np.sum(arr1)                                                                                          │
# │    5 x2 = np.sum(arr2)                                                                                          │
# │    6                                                                                                            │
# │    7 p1 = x1 / n1                                                                                               │
# │    8 p2 = x2 / n2                                                                                               │
# │    9                                                                                                            │
# │   10 p_pooled = (x1 + x2) / (n1 + n2)                                                                           │
# │   11                                                                                                            │
# │   12 se_diff = np.sqrt(p_pooled * (1 - p_pooled) * (1/n1 + 1/n2))                                               │
# │   13                                                                                                            │
# │   14 z_statistic = (p1 - p2) / se_diff                                                                          │
# │   15                                                                                                            │
# │   16 p_value = 2 * stats.norm.sf(np.abs(z_statistic))                                                           │
# │   17                                                                                                            │
# │   18 output = p_value                                                                                           │
# │   19 metadata = "scalar: p-value from a two-sample z-test for proportions"                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ✗ Error executing code: name 'stats' is not defined
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Execution returned None.                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 2/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 import numpy as np                                                                                         │
# │    2 from scipy import stats                                                                                    │
# │    3                                                                                                            │
# │    4 n1 = len(arr1)                                                                                             │
# │    5 n2 = len(arr2)                                                                                             │
# │    6                                                                                                            │
# │    7 x1 = np.sum(arr1 == 1) # Count of 1s in arr1                                                               │
# │    8 x2 = np.sum(arr2 == 1) # Count of 1s in arr2                                                               │
# │    9                                                                                                            │
# │   10 p1_hat = x1 / n1                                                                                           │
# │   11 p2_hat = x2 / n2                                                                                           │
# │   12                                                                                                            │
# │   13 p_pooled = (x1 + x2) / (n1 + n2)                                                                           │
# │   14                                                                                                            │
# │   15 SE = np.sqrt(p_pooled * (1 - p_pooled) * (1/n1 + 1/n2))                                                    │
# │   16                                                                                                            │
# │   17 z_statistic = (p1_hat - p2_hat) / SE                                                                       │
# │   18 p_value = 2 * stats.norm.sf(abs(z_statistic)) # Two-tailed p-value                                         │
# │   19                                                                                                            │
# │   20 output = {"z_statistic": z_statistic, "p_value": p_value}                                                  │
# │   21 metadata = "dictionary containing the z-statistic and p-value for the two-sample proportion z-test"        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# {'z_statistic': np.float64(-0.8716548604640172), 'p_value': np.float64(0.3833966925145822)}
# dictionary containing the z-statistic and p-value for the two-sample proportion z-test
# ╭─────────────────────────────────────────────────── Judgment ────────────────────────────────────────────────────╮
# │ ✓ correctly interprets the query                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  {'z_statistic': np.float64(-0.8716548604640172), 'p_value': np.float64(0.3833966925145822)}                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value={'z_statistic': np.float64(-0.8716548604640172), 'p_value': np.float64(0.3833966925145822)} code='import numpy as np\nfrom scipy import stats\n\nn1 = len(arr1)\nn2 = len(arr2)\n\nx1 = np.sum(arr1 == 1) # Count of 1s in arr1\nx2 = np.sum(arr2 == 1) # Count of 1s in arr2\n\np1_hat = x1 / n1\np2_hat = x2 / n2\n\np_pooled = (x1 + x2) / (n1 + n2)\n\nSE = np.sqrt(p_pooled * (1 - p_pooled) * (1/n1 + 1/n2))\n\nz_statistic = (p1_hat - p2_hat) / SE\np_value = 2 * stats.norm.sf(abs(z_statistic)) # Two-tailed p-value\n\noutput = {"z_statistic": z_statistic, "p_value": p_value}\nmetadata = "dictionary containing the z-statistic and p-value for the two-sample proportion z-test"' description='dictionary containing the z-statistic and p-value for the two-sample proportion z-test' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=2 errors=['Attempt 1: execution returned None.']

# %%
print(sess.chat("Which group performed better, and is the difference significant?"))
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Which group performed better, and is the difference significant?                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 import numpy as np                                                                                         │
# │    2 from scipy import stats                                                                                    │
# │    3                                                                                                            │
# │    4 # Calculate means                                                                                          │
# │    5 mean_arr1 = np.mean(arr1)                                                                                  │
# │    6 mean_arr2 = np.mean(arr2)                                                                                  │
# │    7                                                                                                            │
# │    8 # Perform independent samples t-test                                                                       │
# │    9 t_stat, p_value = stats.ttest_ind(arr1, arr2)                                                              │
# │   10                                                                                                            │
# │   11 # Determine which group performed better                                                                   │
# │   12 if mean_arr1 > mean_arr2:                                                                                  │
# │   13     better_group = "Group 1"                                                                               │
# │   14 else:                                                                                                      │
# │   15     better_group = "Group 2"                                                                               │
# │   16                                                                                                            │
# │   17 # Determine significance                                                                                   │
# │   18 alpha = 0.05  # Standard significance level                                                                │
# │   19 if p_value < alpha:                                                                                        │
# │   20     significance_statement = "The difference is statistically significant."                                │
# │   21 else:                                                                                                      │
# │   22     significance_statement = "The difference is not statistically significant."                            │
# │   23                                                                                                            │
# │   24 # Construct a concise conclusion                                                                           │
# │   25 conclusion_message = f"{better_group} performed better (Mean of Group 1: {mean_arr1:.4f}, Mean of Group 2: │
# │   26                                                                                                            │
# │   27 output = {                                                                                                 │
# │   28     "mean_arr1": mean_arr1,                                                                                │
# │   29     "mean_arr2": mean_arr2,                                                                                │
# │   30     "t_statistic": t_stat,                                                                                 │
# │   31     "p_value": p_value,                                                                                    │
# │   32     "better_group": better_group,                                                                          │
# │   33     "significance_statement": significance_statement,                                                      │
# │   34     "conclusion": conclusion_message                                                                       │
# │   35 }                                                                                                          │
# │   36 metadata = "Dictionary containing the means of both groups, t-statistic, p-value, the better performing gr │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# {'mean_arr1': np.float64(0.1), 'mean_arr2': np.float64(0.112), 't_statistic': np.float64(-0.8713844553435877),
# 'p_value': np.float64(0.38364896061020115), 'better_group': 'Group 2', 'significance_statement': 'The difference is
# not statistically significant.', 'conclusion': 'Group 2 performed better (Mean of Group 1: 0.1000, Mean of Group 2:
# 0.1120). The difference is not statistically significant. (p-value: 0.3836).'}
# Dictionary containing the means of both groups, t-statistic, p-value, the better performing group, a statement on
# statistical significance, and a concise conclusion.
# ╭─────────────────────────────────────────────────── Judgment ────────────────────────────────────────────────────╮
# │ ✓ correctly interprets the query                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  {'mean_arr1': np.float64(0.1), 'mean_arr2': np.float64(0.112), 't_statistic': np.float64(-0.8713844553435877), │
# │ 'p_value': np.float64(0.38364896061020115), 'better_group': 'Group 2', 'significance_statement': 'The           │
# │ difference is not statistically significant.', 'conclusion': 'Group 2 performed better (Mean of Group 1:        │
# │ 0.1000, Mean of Group 2: 0.1120). The difference is not statistically significant. (p-value: 0.3836).'}         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# value={'mean_arr1': np.float64(0.1), 'mean_arr2': np.float64(0.112), 't_statistic': np.float64(-0.8713844553435877), 'p_value': np.float64(0.38364896061020115), 'better_group': 'Group 2', 'significance_statement': 'The difference is not statistically significant.', 'conclusion': 'Group 2 performed better (Mean of Group 1: 0.1000, Mean of Group 2: 0.1120). The difference is not statistically significant. (p-value: 0.3836).'} code='import numpy as np\nfrom scipy import stats\n\n# Calculate means\nmean_arr1 = np.mean(arr1)\nmean_arr2 = np.mean(arr2)\n\n# Perform independent samples t-test\nt_stat, p_value = stats.ttest_ind(arr1, arr2)\n\n# Determine which group performed better\nif mean_arr1 > mean_arr2:\n    better_group = "Group 1"\nelse:\n    better_group = "Group 2"\n\n# Determine significance\nalpha = 0.05  # Standard significance level\nif p_value < alpha:\n    significance_statement = "The difference is statistically significant."\nelse:\n    significance_statement = "The difference is not statistically significant."\n\n# Construct a concise conclusion\nconclusion_message = f"{better_group} performed better (Mean of Group 1: {mean_arr1:.4f}, Mean of Group 2: {mean_arr2:.4f}). {significance_statement} (p-value: {p_value:.4f})."\n\noutput = {\n    "mean_arr1": mean_arr1,\n    "mean_arr2": mean_arr2,\n    "t_statistic": t_stat,\n    "p_value": p_value,\n    "better_group": better_group,\n    "significance_statement": significance_statement,\n    "conclusion": conclusion_message\n}\nmetadata = "Dictionary containing the means of both groups, t-statistic, p-value, the better performing group, a statement on statistical significance, and a concise conclusion."' description='Dictionary containing the means of both groups, t-statistic, p-value, the better performing group, a statement on statistical significance, and a concise conclusion.' judgment=Judgment(interprets_query_correctly=True, reason='') attempts=1 errors=[]
